# %%
import pandas as pd
from pathlib import Path

EVENTS_DIR = Path("events")
TRANSFERS_DIR = Path("transfers")


events_df = pd.read_csv(EVENTS_DIR.joinpath("events.csv"))
game_info_df = pd.read_csv(EVENTS_DIR.joinpath("ginf.csv"))
event_game_info_df = pd.merge(events_df, game_info_df, on='id_odsp', how='inner')
transfers_df = pd.read_csv(TRANSFERS_DIR.joinpath("transfers.csv"))

# %%
player_name = 'Luis Suarez'

# %%
player_event_game_info = event_game_info_df[event_game_info_df['player'] == player_name.lower()]
player_event_game_info
# Out:
#           id_odsp    id_event  sort_order  time  \
# 331558  l89fA1AI/   l89fA1AI3           3     5
# 331571  l89fA1AI/  l89fA1AI16          16    13
# 331585  l89fA1AI/  l89fA1AI30          30    31
# 331599  l89fA1AI/  l89fA1AI44          44    46
# 331604  l89fA1AI/  l89fA1AI49          49    51
# ...           ...         ...         ...   ...
# 939420  G0pLytmF/  G0pLytmF16          16    11
# 939426  G0pLytmF/  G0pLytmF22          22    20
# 939457  G0pLytmF/  G0pLytmF53          53    45
# 939471  G0pLytmF/  G0pLytmF69          69    68
# 939474  G0pLytmF/  G0pLytmF72          72    72
#
#                                                      text  event_type  \
# 331558  Luis Suarez (Liverpool) wins a free kick in th...           8
# 331571  Goal!        Goal!  Liverpool 1, Crystal Palac...           1
# 331585  Offside, Liverpool. Jose Enrique tries a throu...           9
# 331599  Attempt saved. Luis Suarez (Liverpool) right f...           1
# 331604  Offside, Liverpool. Victor Moses tries a throu...           9
# ...                                                   ...         ...
# 939420  Attempt missed. Luis Suarez (Barcelona) right ...           1
# 939426  Attempt missed. Luis Suarez (Barcelona) right ...           1
# 939457  Luis Suarez (Barcelona) hits the right post wi...           1
# 939471  Goal!  Eibar 0, Barcelona 3. Luis Suarez (Barc...           1
# 939474  Attempt blocked. Luis Suarez (Barcelona) right...           1
#
#         event_type2  side event_team        opponent  ...              at  \
# 331558          NaN     1  Liverpool  Crystal Palace  ...  Crystal Palace
# 331571         12.0     1  Liverpool  Crystal Palace  ...  Crystal Palace
# 331585         13.0     1  Liverpool  Crystal Palace  ...  Crystal Palace
# 331599          NaN     1  Liverpool  Crystal Palace  ...  Crystal Palace
# 331604         13.0     1  Liverpool  Crystal Palace  ...  Crystal Palace
# ...             ...   ...        ...             ...  ...             ...
# 939420         12.0     2  Barcelona           Eibar  ...       Barcelona
# 939426         12.0     2  Barcelona           Eibar  ...       Barcelona
# 939457         12.0     2  Barcelona           Eibar  ...       Barcelona
# 939471          NaN     2  Barcelona           Eibar  ...       Barcelona
# 939474         12.0     2  Barcelona           Eibar  ...       Barcelona
#
#        fthg ftag  odd_h  odd_d  odd_a  odd_over  odd_under  odd_bts  odd_bts_n
# 331558    3    1   1.23   8.25  21.00       NaN        NaN      NaN        NaN
# 331571    3    1   1.23   8.25  21.00       NaN        NaN      NaN        NaN
# 331585    3    1   1.23   8.25  21.00       NaN        NaN      NaN        NaN
# 331599    3    1   1.23   8.25  21.00       NaN        NaN      NaN        NaN
# 331604    3    1   1.23   8.25  21.00       NaN        NaN      NaN        NaN
# ...     ...  ...    ...    ...    ...       ...        ...      ...        ...
# 939420    0    4  12.00   6.50   1.33      1.47       2.96      1.8       2.11
# 939426    0    4  12.00   6.50   1.33      1.47       2.96      1.8       2.11
# 939457    0    4  12.00   6.50   1.33      1.47       2.96      1.8       2.11
# 939471    0    4  12.00   6.50   1.33      1.47       2.96      1.8       2.11
# 939474    0    4  12.00   6.50   1.33      1.47       2.96      1.8       2.11
#
# [908 rows x 39 columns]

# %%
player_transfers = transfers_df[transfers_df['player_name'] == player_name]
player_transfers
# Out:
# Empty DataFrame
# Columns: [league, season, window, team_id, team_name, team_country, dir, player_id, player_name, player_age, player_nation, player_nation2, player_pos, counter_team_id, counter_team_name, counter_team_country, transfer_fee_amnt, market_val_amnt, is_free, is_loan, is_loan_end, is_retired, transfer_id]
# Index: []
#
# [0 rows x 23 columns]

# %%
player_event_game_info.to_json(Path(player_name).with_suffix(".json"), orient='index', indent=2)
